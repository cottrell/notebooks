# %% [markdown]
# # Test note
#
# Something exists
#
# $$ \int_0^1 f(x) \text{d} x $$
#
# here.
#
# ## And more
#
# stuff

# %%
# %matplotlib inline
import numpy.random as nr
from pylab import *
figure(figsize=(12, 4))
plot(np.cumsum(nr.randn(100)), alpha=0.5, linewidth=2)
grid()
